# %%
# %matplotlib notebook
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from scipy.io import wavfile as wav
from scipy import signal as sig
import simpleaudio as sa
import decimal
from decimal import *

# %%
# Defining some input values. This code is generating the FFT for a signal with two sin waves
fs = 8000
t = np.arange(0, 0.25, 1/fs)

# this is the signal we are performing the FFT on 
d0 = np.sin(2*np.pi*941*t) + np.sin(2*np.pi*1336*t)
N = 4096
pause = np.zeros(int(0.5*fs))

# some stuff we do because we're working with audio signals
d0twice = np.concatenate([d0, pause])
d0twice = np.concatenate([d0twice, d0])
d0twice = wav.write('d0Audio', fs, d0twice.astype('int16'))

xf = np.fft.fft(d0, N)
# FFT of time signal x nfft frequency samples
d0_ft = abs(np.fft.fftshift(xf))

f = np.arange(-4000, 4000, 8000/N)
fig = plt.figure(1)
plt.subplot(2, 1, 1)
plt.plot(f, d0_ft)

#observing the plot gives frequencies of approx 900 and 1300
threshold = 800
ind = np.arange(len(d0_ft))
b = ind[d0_ft[ind] > threshold] 
print(f[b])

n = np.random.normal(0,1,len(d0))
d0n = d0 + n

xf2 = np.fft.fft(d0n, N)
# FFT of time signal x nfft frequency samples
d0n_ft = abs(np.fft.fftshift(xf2))
plt.subplot(2,1,2)
plt.plot(f, d0n_ft)
# Out:
# <img src="data:image/png;base64,..." width="640">
# [-1335.9375   -941.40625   941.40625  1335.9375 ]

# %%
def classify(x, fs):
    tones = np.matrix([697, 770, 852], [1209, 1336, 1477])
    tones = np.transpose(tones)
    N = 4096
    f = np.arange(-fs/2, fs/2, fs/N)
    xf = np.fft.fft(x, N)
    # FFT of time signal x nfft frequency samples
    xfft_abs = abs(np.fft.fftshift(xf))
    threshold = 800
    index_tones = np.arange(len(x_ft))
    freq_tone = index_tones[x_ft[ind] > threshold] 
    print(f[b])

# %%
t = np.arange(0, 0.25, 1/8000)
d4 = np.sin(2*np.pi*770*t) + np.sin(2*np.pi*1209*t)
d5 = np.sin(2*np.pi*770*t) + np.sin(2*np.pi*1336*t)
d8 = np.sin(2*np.pi*852*t) + np.sin(2*np.pi*1336*t)
d9 = np.sin(2*np.pi*852*t) + np.sin(2*np.pi*1477*t)

classify(d4, 8000)
classify(d5, 8000)
classify(d8, 8000)
classify(d9, 8000)


# To ensure high detection accuracy with noise, we can raise the threshold
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-6eade4053b25> in <module>
#       5 d9 = np.sin(2*np.pi*852*t) + np.sin(2*np.pi*1477*t)
#       6
# ----> 7 classify(d4, 8000)
#       8 classify(d5, 8000)
#       9 classify(d8, 8000)
#
# <ipython-input-18-691f52f679ae> in classify(x, fs)
#       1 def classify(x, fs):
# ----> 2     tones = np.matrix([697, 770, 852], [1209, 1336, 1477])
#       3     tones = np.transpose(tones)
#       4     N = 4096
#       5     f = np.arange(-fs/2, fs/2, fs/N)
#
# ~\Anaconda3\lib\site-packages\numpy\matrixlib\defmatrix.py in __new__(subtype, data, dtype, copy)
#     140
#     141         # now convert data to an array
# --> 142         arr = N.array(data, dtype=dtype, copy=copy)
#     143         ndim = arr.ndim
#     144         shape = arr.shape
#
# TypeError: data type not understood

# %%
file = open('phonenum.csv','rb')
phonenum_csv = np.loadtxt(file, delimiter = ',')
fs = 8000

phone_num = np.ones(11) * -1

# 4000 samples in each time slice
# 44000 samples total 
end_index = 0
for i in np.arange(0, len(phone_num), 1): 
    start_index = end_index
    if i = 11:
        
    end_index = start_index + 4000
    signal = phonenum_csv[start_index: end_index]
    

#Summary. In this lab, we converted signals from the time domain to the frequency domain using the FFT function. Using a phone number based identification task, we learned the caveats of implementing the FFT to identify the frequency components of signals, such as handling noise.
